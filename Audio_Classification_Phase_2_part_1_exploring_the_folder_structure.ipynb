# %%
import os

# %% [markdown]
# # First let us go through some important os functions

# %%
# This function helps us obtain the current directory I am in
os.getcwd()
# Out:
# '/content'

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# This function helps us obtain the current directory I am in
os.getcwd()
# Out:
# '/content'

# %%
# This function enables us to change my current directory
os.chdir('/content/drive/MyDrive/Audio Binary Classification/cats_dogs')
os.getcwd()
# Out:
# '/content/drive/MyDrive/Audio Binary Classification/cats_dogs'

# %%
# This function enables us list all folders within our current directory
os.listdir()
# Out:
# ['train', 'test']

# %%
# This function checks if a particular file/folder exists in our current directory
os.path.exists('test')
# Out:
# True

# %%
# This function creates a new folder in the current directory
os.mkdir('new_folder')

# %%
os.listdir()
# Out:
# ['train', 'test', 'new_folder']

# %%
# This function removes an empty folder from the current directory

os.rmdir('new_folder')

# %%
os.listdir()
# Out:
# ['train', 'test']

# %%
# Can join file/folder names for various purposes
os.path.join(os.getcwd(), 'test')
# Out:
# '/content/drive/MyDrive/Audio Binary Classification/cats_dogs/test'

# %%
os.path.exists(os.path.join(os.getcwd(), 'test'))
# Out:
# True

# %% [markdown]
# # Coming back to the original directory

# %%
os.chdir('/content')

# %%
os.getcwd()
# Out:
# '/content'

# %%
path ='/content/drive/MyDrive/Audio Binary Classification/cats_dogs/train'
os.chdir(path)
print("UPDATED DIR",os.getcwd())
labels = [name for name in os.listdir('.') if os.path.isdir(name)]
print(f'Total Labels: {len(labels)} \n')
labels
# Out:
# UPDATED DIR /content/drive/MyDrive/Audio Binary Classification/cats_dogs/train
# Total Labels: 2
# ['dog', 'cat']

# %%
os.getcwd()
# Out:
# '/content/drive/MyDrive/Audio Binary Classification/cats_dogs/train'

# %%
dog_file_path = os.path.join(os.getcwd(),'dog','dog_barking_0.wav')
os.path.exists(dog_file_path)
# Out:
# True
